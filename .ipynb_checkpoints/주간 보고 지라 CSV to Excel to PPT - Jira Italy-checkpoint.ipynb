# %%
import pandas as pd
import numpy as np
import datetime

# %%
csv_all = pd.read_csv("HAEE JIRA Current.csv")

# %%
csv_all
# Out:
#             Issue Type  Issue key  Issue id  \
# 0                  Bug  KIMSC-171    171710
# 1                  Bug  KIMSC-170    171574
# 2                 Task  KIMSC-169    171541
# 3                 Task  KIMSC-168    170589
# 4      Service Request  KIMSC-167    170491
# ..                 ...        ...       ...
# 157  General Inquiries    KIMSC-7    129454
# 158                Bug    KIMSC-6    129308
# 159                Bug    KIMSC-5    129142
# 160                Bug    KIMSC-4    129141
# 161                Bug    KIMSC-3    129139
#
#                                                Summary          Assignee  \
# 0                          Payment invoice for dealers          soyu.bae
# 1         Plate GC396JV - Change Status of the vehicle          soyu.bae
# 2                    Change Message In KiaMobility APP          soyu.bae
# 3    CLONE - Insert Privacy Link (PDF) in the confi...  valentina.aloisi
# 4                               Customer survey email.     haee.mobility
# ..                                                 ...               ...
# 157                   Support on FMS/app demonstration      sookyung.kim
# 158            Bug register reservation - Kia Mobility      sookyung.kim
# 159             KiaMobility - Error - Driver's license    Nikolai.Psarev
# 160         Vehicle information (Transmission) modify       sookyung.kim
# 161  Kia Mobility bug - Log out & customer data res...      sookyung.kim
#
#              Reporter       Priority                     Status Resolution  \
# 0    valentina.aloisi      P2 - High             Initial triage        NaN
# 1       paola.panzeri      P2 - High             Initial triage        NaN
# 2    valentina.aloisi      P2 - High             Initial triage        NaN
# 3    valentina.aloisi  P1 - Critical  Customer Resolution Check        NaN
# 4         SunJung.Ryu    P3 - Medium             Initial triage        NaN
# ..                ...            ...                        ...        ...
# 157       SunJung.Ryu    P3 - Medium                       Done       Done
# 158    Nikolai.Psarev      P2 - High                       Done       Done
# 159    Nikolai.Psarev      P2 - High                       Done       Done
# 160  valentina.aloisi      P2 - High                       Done       Done
# 161       SunJung.Ryu    P3 - Medium                       Done       Done
#
#               Created           Updated  Due Date
# 0    2021-08-06 09:37  2021-08-06 09:37       NaN
# 1    2021-08-05 09:39  2021-08-06 09:27       NaN
# 2    2021-08-04 18:14  2021-08-04 18:14       NaN
# 3    2021-07-28 10:33  2021-08-04 09:04       NaN
# 4    2021-07-27 14:49  2021-07-28 12:01       NaN
# ..                ...               ...       ...
# 157  2020-11-06 11:32  2020-11-23 10:04       NaN
# 158  2020-11-05 11:07  2020-11-12 09:50       NaN
# 159  2020-11-04 09:37  2020-12-31 04:25       NaN
# 160  2020-11-04 09:33  2020-11-18 13:33       NaN
# 161  2020-11-04 09:23  2020-11-23 10:50       NaN
#
# [162 rows x 12 columns]

# %%
csv_all["sequece"] = csv_all["Issue key"].str[6:].astype(int)

# %%
csv_all
# Out:
#             Issue Type  Issue key  Issue id  \
# 0                  Bug  KIMSC-171    171710
# 1                  Bug  KIMSC-170    171574
# 2                 Task  KIMSC-169    171541
# 3                 Task  KIMSC-168    170589
# 4      Service Request  KIMSC-167    170491
# ..                 ...        ...       ...
# 157  General Inquiries    KIMSC-7    129454
# 158                Bug    KIMSC-6    129308
# 159                Bug    KIMSC-5    129142
# 160                Bug    KIMSC-4    129141
# 161                Bug    KIMSC-3    129139
#
#                                                Summary          Assignee  \
# 0                          Payment invoice for dealers          soyu.bae
# 1         Plate GC396JV - Change Status of the vehicle          soyu.bae
# 2                    Change Message In KiaMobility APP          soyu.bae
# 3    CLONE - Insert Privacy Link (PDF) in the confi...  valentina.aloisi
# 4                               Customer survey email.     haee.mobility
# ..                                                 ...               ...
# 157                   Support on FMS/app demonstration      sookyung.kim
# 158            Bug register reservation - Kia Mobility      sookyung.kim
# 159             KiaMobility - Error - Driver's license    Nikolai.Psarev
# 160         Vehicle information (Transmission) modify       sookyung.kim
# 161  Kia Mobility bug - Log out & customer data res...      sookyung.kim
#
#              Reporter       Priority                     Status Resolution  \
# 0    valentina.aloisi      P2 - High             Initial triage        NaN
# 1       paola.panzeri      P2 - High             Initial triage        NaN
# 2    valentina.aloisi      P2 - High             Initial triage        NaN
# 3    valentina.aloisi  P1 - Critical  Customer Resolution Check        NaN
# 4         SunJung.Ryu    P3 - Medium             Initial triage        NaN
# ..                ...            ...                        ...        ...
# 157       SunJung.Ryu    P3 - Medium                       Done       Done
# 158    Nikolai.Psarev      P2 - High                       Done       Done
# 159    Nikolai.Psarev      P2 - High                       Done       Done
# 160  valentina.aloisi      P2 - High                       Done       Done
# 161       SunJung.Ryu    P3 - Medium                       Done       Done
#
#               Created           Updated  Due Date  sequece
# 0    2021-08-06 09:37  2021-08-06 09:37       NaN      171
# 1    2021-08-05 09:39  2021-08-06 09:27       NaN      170
# 2    2021-08-04 18:14  2021-08-04 18:14       NaN      169
# 3    2021-07-28 10:33  2021-08-04 09:04       NaN      168
# 4    2021-07-27 14:49  2021-07-28 12:01       NaN      167
# ..                ...               ...       ...      ...
# 157  2020-11-06 11:32  2020-11-23 10:04       NaN        7
# 158  2020-11-05 11:07  2020-11-12 09:50       NaN        6
# 159  2020-11-04 09:37  2020-12-31 04:25       NaN        5
# 160  2020-11-04 09:33  2020-11-18 13:33       NaN        4
# 161  2020-11-04 09:23  2020-11-23 10:50       NaN        3
#
# [162 rows x 13 columns]

# %%
csv_all = csv_all.sort_values(by='sequece')

# %%
csv_all
# Out:
#             Issue Type  Issue key  Issue id  \
# 161                Bug    KIMSC-3    129139
# 160                Bug    KIMSC-4    129141
# 159                Bug    KIMSC-5    129142
# 158                Bug    KIMSC-6    129308
# 157  General Inquiries    KIMSC-7    129454
# ..                 ...        ...       ...
# 4      Service Request  KIMSC-167    170491
# 3                 Task  KIMSC-168    170589
# 2                 Task  KIMSC-169    171541
# 1                  Bug  KIMSC-170    171574
# 0                  Bug  KIMSC-171    171710
#
#                                                Summary          Assignee  \
# 161  Kia Mobility bug - Log out & customer data res...      sookyung.kim
# 160         Vehicle information (Transmission) modify       sookyung.kim
# 159             KiaMobility - Error - Driver's license    Nikolai.Psarev
# 158            Bug register reservation - Kia Mobility      sookyung.kim
# 157                   Support on FMS/app demonstration      sookyung.kim
# ..                                                 ...               ...
# 4                               Customer survey email.     haee.mobility
# 3    CLONE - Insert Privacy Link (PDF) in the confi...  valentina.aloisi
# 2                    Change Message In KiaMobility APP          soyu.bae
# 1         Plate GC396JV - Change Status of the vehicle          soyu.bae
# 0                          Payment invoice for dealers          soyu.bae
#
#              Reporter       Priority                     Status Resolution  \
# 161       SunJung.Ryu    P3 - Medium                       Done       Done
# 160  valentina.aloisi      P2 - High                       Done       Done
# 159    Nikolai.Psarev      P2 - High                       Done       Done
# 158    Nikolai.Psarev      P2 - High                       Done       Done
# 157       SunJung.Ryu    P3 - Medium                       Done       Done
# ..                ...            ...                        ...        ...
# 4         SunJung.Ryu    P3 - Medium             Initial triage        NaN
# 3    valentina.aloisi  P1 - Critical  Customer Resolution Check        NaN
# 2    valentina.aloisi      P2 - High             Initial triage        NaN
# 1       paola.panzeri      P2 - High             Initial triage        NaN
# 0    valentina.aloisi      P2 - High             Initial triage        NaN
#
#               Created           Updated  Due Date  sequece
# 161  2020-11-04 09:23  2020-11-23 10:50       NaN        3
# 160  2020-11-04 09:33  2020-11-18 13:33       NaN        4
# 159  2020-11-04 09:37  2020-12-31 04:25       NaN        5
# 158  2020-11-05 11:07  2020-11-12 09:50       NaN        6
# 157  2020-11-06 11:32  2020-11-23 10:04       NaN        7
# ..                ...               ...       ...      ...
# 4    2021-07-27 14:49  2021-07-28 12:01       NaN      167
# 3    2021-07-28 10:33  2021-08-04 09:04       NaN      168
# 2    2021-08-04 18:14  2021-08-04 18:14       NaN      169
# 1    2021-08-05 09:39  2021-08-06 09:27       NaN      170
# 0    2021-08-06 09:37  2021-08-06 09:37       NaN      171
#
# [162 rows x 13 columns]

# %%
csv_all['Region'] = "ITA"

# %%
csv_all = csv_all.rename(columns={'Issue Type':'Type', 'Issue key':'ID',"Summary":"Description","Created":"Reported Date","Updated":"Resolved date" })

# %%
csv_all = csv_all[['Region','Type',"ID","Description","Reporter","Status","Reported Date","Resolved date"]]

# %%
csv_all.index = np.arange(1, len(csv_all)+1)

# %%
csv_all
# Out:
#     Region               Type         ID  \
# 1      ITA                Bug    KIMSC-3
# 2      ITA                Bug    KIMSC-4
# 3      ITA                Bug    KIMSC-5
# 4      ITA                Bug    KIMSC-6
# 5      ITA  General Inquiries    KIMSC-7
# ..     ...                ...        ...
# 158    ITA    Service Request  KIMSC-167
# 159    ITA               Task  KIMSC-168
# 160    ITA               Task  KIMSC-169
# 161    ITA                Bug  KIMSC-170
# 162    ITA                Bug  KIMSC-171
#
#                                            Description          Reporter  \
# 1    Kia Mobility bug - Log out & customer data res...       SunJung.Ryu
# 2           Vehicle information (Transmission) modify   valentina.aloisi
# 3               KiaMobility - Error - Driver's license    Nikolai.Psarev
# 4              Bug register reservation - Kia Mobility    Nikolai.Psarev
# 5                     Support on FMS/app demonstration       SunJung.Ryu
# ..                                                 ...               ...
# 158                             Customer survey email.       SunJung.Ryu
# 159  CLONE - Insert Privacy Link (PDF) in the confi...  valentina.aloisi
# 160                  Change Message In KiaMobility APP  valentina.aloisi
# 161       Plate GC396JV - Change Status of the vehicle     paola.panzeri
# 162                        Payment invoice for dealers  valentina.aloisi
#
#                         Status     Reported Date     Resolved date
# 1                         Done  2020-11-04 09:23  2020-11-23 10:50
# 2                         Done  2020-11-04 09:33  2020-11-18 13:33
# 3                         Done  2020-11-04 09:37  2020-12-31 04:25
# 4                         Done  2020-11-05 11:07  2020-11-12 09:50
# 5                         Done  2020-11-06 11:32  2020-11-23 10:04
# ..                         ...               ...               ...
# 158             Initial triage  2021-07-27 14:49  2021-07-28 12:01
# 159  Customer Resolution Check  2021-07-28 10:33  2021-08-04 09:04
# 160             Initial triage  2021-08-04 18:14  2021-08-04 18:14
# 161             Initial triage  2021-08-05 09:39  2021-08-06 09:27
# 162             Initial triage  2021-08-06 09:37  2021-08-06 09:37
#
# [162 rows x 8 columns]

# %%
# reporter mapping

# %%
csv_all.Reporter.unique()
# Out:
# array(['SunJung.Ryu', 'valentina.aloisi', 'Nikolai.Psarev',
#        'giulio.lingesso', 'lorenzo.martini', 'bongjoo.kim', 'yumi.song',
#        'soyu.bae', 'paola.panzeri'], dtype=object)

# %%
reporters = {'soyu.bae':'HAE','paola.panzeri':'KMIT','lorenzo.martini':'KMIT','valentina.aloisi':'KMIT',"SunJung.Ryu":"KME","giulio.lingesso":"KME",'Nikolai.Psarev':"KMIT","yumi.song":"HAE" }
csv_all = csv_all.replace({"Reporter":reporters})

# %%
csv_all.iloc[56]
# Out:
# Region                        ITA
# Type                         Task
# ID                       KIMSC-60
# Description            Admin user
# Reporter                     KMIT
# Status                       Done
# Reported Date    2021-02-23 20:03
# Resolved date    2021-02-26 09:28
# Name: 57, dtype: object

# %%
#csv_all = csv_all.drop([56])

# %%
len(csv_all)
# Out:
# 162

# %%
csv_all.iloc[50:]
# Out:
#     Region             Type         ID  \
# 51     ITA              Bug   KIMSC-54
# 52     ITA      Improvement   KIMSC-55
# 53     ITA      Improvement   KIMSC-56
# 54     ITA      Improvement   KIMSC-57
# 55     ITA      Improvement   KIMSC-58
# ..     ...              ...        ...
# 158    ITA  Service Request  KIMSC-167
# 159    ITA             Task  KIMSC-168
# 160    ITA             Task  KIMSC-169
# 161    ITA              Bug  KIMSC-170
# 162    ITA              Bug  KIMSC-171
#
#                                            Description       Reporter  \
# 51                App - driver's license registration             KME
# 52                                Sprint #4 - OVERVIEW           KMIT
# 53                            Sprint #4 - Dashboard_03           KMIT
# 54                        Sprint #4 - CRM Integration            KMIT
# 55    Sprint #4 - SCA (Strong Customer Authentication)           KMIT
# ..                                                 ...            ...
# 158                             Customer survey email.            KME
# 159  CLONE - Insert Privacy Link (PDF) in the confi...           KMIT
# 160                  Change Message In KiaMobility APP           KMIT
# 161       Plate GC396JV - Change Status of the vehicle  paola.panzeri
# 162                        Payment invoice for dealers           KMIT
#
#                         Status     Reported Date     Resolved date
# 51                        Done  2021-02-03 18:07  2021-03-11 00:58
# 52                        Done  2021-02-12 11:02  2021-03-05 07:56
# 53                        Done  2021-02-12 11:06  2021-04-12 07:01
# 54                        Done  2021-02-12 11:13  2021-05-19 14:45
# 55                        Done  2021-02-12 11:16  2021-03-11 01:35
# ..                         ...               ...               ...
# 158             Initial triage  2021-07-27 14:49  2021-07-28 12:01
# 159  Customer Resolution Check  2021-07-28 10:33  2021-08-04 09:04
# 160             Initial triage  2021-08-04 18:14  2021-08-04 18:14
# 161             Initial triage  2021-08-05 09:39  2021-08-06 09:27
# 162             Initial triage  2021-08-06 09:37  2021-08-06 09:37
#
# [112 rows x 8 columns]

# %%
# Status Mapping

# %%
csv_all.Status.unique()
# Out:
# array(['Done', 'Service Desk Notification', 'Issue Management',
#        'Customer Resolution Check', 'Initial triage'], dtype=object)

# %%
status = {"Done":"Done", 
          "Issue Management":"In development",
          'Customer Resolution Check':'Awaiting confirmation',
          'Initial triage':'In review',
          'Service Desk Notification':'In development',
          'Further Investigation':"In review",
          "Clarification Required":"In review"}

# %%
status
# Out:
# {'Done': 'Done',
#  'Issue Management': 'In development',
#  'Customer Resolution Check': 'Awaiting confirmation',
#  'Initial triage': 'In review',
#  'Service Desk Notification': 'In development',
#  'Further Investigation': 'In review',
#  'Clarification Required': 'In review'}

# %%
csv_all = csv_all.replace({"Status":status})

# %%
csv_all
# Out:
#     Region               Type         ID  \
# 1      ITA                Bug    KIMSC-3
# 2      ITA                Bug    KIMSC-4
# 3      ITA                Bug    KIMSC-5
# 4      ITA                Bug    KIMSC-6
# 5      ITA  General Inquiries    KIMSC-7
# ..     ...                ...        ...
# 158    ITA    Service Request  KIMSC-167
# 159    ITA               Task  KIMSC-168
# 160    ITA               Task  KIMSC-169
# 161    ITA                Bug  KIMSC-170
# 162    ITA                Bug  KIMSC-171
#
#                                            Description       Reporter  \
# 1    Kia Mobility bug - Log out & customer data res...            KME
# 2           Vehicle information (Transmission) modify            KMIT
# 3               KiaMobility - Error - Driver's license           KMIT
# 4              Bug register reservation - Kia Mobility           KMIT
# 5                     Support on FMS/app demonstration            KME
# ..                                                 ...            ...
# 158                             Customer survey email.            KME
# 159  CLONE - Insert Privacy Link (PDF) in the confi...           KMIT
# 160                  Change Message In KiaMobility APP           KMIT
# 161       Plate GC396JV - Change Status of the vehicle  paola.panzeri
# 162                        Payment invoice for dealers           KMIT
#
#                     Status     Reported Date     Resolved date
# 1                     Done  2020-11-04 09:23  2020-11-23 10:50
# 2                     Done  2020-11-04 09:33  2020-11-18 13:33
# 3                     Done  2020-11-04 09:37  2020-12-31 04:25
# 4                     Done  2020-11-05 11:07  2020-11-12 09:50
# 5                     Done  2020-11-06 11:32  2020-11-23 10:04
# ..                     ...               ...               ...
# 158              In review  2021-07-27 14:49  2021-07-28 12:01
# 159  Awaiting confirmation  2021-07-28 10:33  2021-08-04 09:04
# 160              In review  2021-08-04 18:14  2021-08-04 18:14
# 161              In review  2021-08-05 09:39  2021-08-06 09:27
# 162              In review  2021-08-06 09:37  2021-08-06 09:37
#
# [162 rows x 8 columns]

# %% [markdown]
# *** Release Planned *** 조심 필수

# %%
csv_all["Reported Date"] = csv_all["Reported Date"].str[:10]

# %%
csv_all["Reported Date"] = pd.to_datetime(csv_all["Reported Date"], format='%Y-%m-%d')

# %%
csv_all.loc[csv_all.Status != 'Done', 'Resolved date'] = ''
csv_all["Resolved date"] = pd.to_datetime(csv_all["Resolved date"], format='%Y-%m-%d')

# %%
csv_all
# Out:
#     Region               Type         ID  \
# 1      ITA                Bug    KIMSC-3
# 2      ITA                Bug    KIMSC-4
# 3      ITA                Bug    KIMSC-5
# 4      ITA                Bug    KIMSC-6
# 5      ITA  General Inquiries    KIMSC-7
# ..     ...                ...        ...
# 158    ITA    Service Request  KIMSC-167
# 159    ITA               Task  KIMSC-168
# 160    ITA               Task  KIMSC-169
# 161    ITA                Bug  KIMSC-170
# 162    ITA                Bug  KIMSC-171
#
#                                            Description       Reporter  \
# 1    Kia Mobility bug - Log out & customer data res...            KME
# 2           Vehicle information (Transmission) modify            KMIT
# 3               KiaMobility - Error - Driver's license           KMIT
# 4              Bug register reservation - Kia Mobility           KMIT
# 5                     Support on FMS/app demonstration            KME
# ..                                                 ...            ...
# 158                             Customer survey email.            KME
# 159  CLONE - Insert Privacy Link (PDF) in the confi...           KMIT
# 160                  Change Message In KiaMobility APP           KMIT
# 161       Plate GC396JV - Change Status of the vehicle  paola.panzeri
# 162                        Payment invoice for dealers           KMIT
#
#                     Status Reported Date       Resolved date
# 1                     Done    2020-11-04 2020-11-23 10:50:00
# 2                     Done    2020-11-04 2020-11-18 13:33:00
# 3                     Done    2020-11-04 2020-12-31 04:25:00
# 4                     Done    2020-11-05 2020-11-12 09:50:00
# 5                     Done    2020-11-06 2020-11-23 10:04:00
# ..                     ...           ...                 ...
# 158              In review    2021-07-27                 NaT
# 159  Awaiting confirmation    2021-07-28                 NaT
# 160              In review    2021-08-04                 NaT
# 161              In review    2021-08-05                 NaT
# 162              In review    2021-08-06                 NaT
#
# [162 rows x 8 columns]

# %%
csv_all["Reported Date"] = csv_all["Reported Date"].dt.strftime('%d-%b-%Y')

# %%
csv_all["Resolved date"] = csv_all["Resolved date"].dt.strftime('%d-%b-%Y')

# %%
csv_bug = csv_all.loc[csv_all.Type == 'Bug']

# %%
csv_inq = csv_all.query('Type == \'General Inquiries\' or Type == \'Service Request\'')

# %%
csv_inq
# Out:
#     Region               Type         ID  \
# 5      ITA  General Inquiries    KIMSC-7
# 10     ITA  General Inquiries   KIMSC-12
# 22     ITA    Service Request   KIMSC-24
# 29     ITA  General Inquiries   KIMSC-31
# 33     ITA  General Inquiries   KIMSC-35
# 37     ITA    Service Request   KIMSC-39
# 40     ITA  General Inquiries   KIMSC-42
# 42     ITA  General Inquiries   KIMSC-45
# 44     ITA  General Inquiries   KIMSC-47
# 45     ITA    Service Request   KIMSC-48
# 56     ITA  General Inquiries   KIMSC-59
# 59     ITA  General Inquiries   KIMSC-62
# 96     ITA    Service Request  KIMSC-101
# 105    ITA    Service Request  KIMSC-110
# 138    ITA  General Inquiries  KIMSC-145
# 158    ITA    Service Request  KIMSC-167
#
#                                 Description     Reporter     Status  \
# 5          Support on FMS/app demonstration          KME       Done
# 10                  Testflight for test APP         KMIT       Done
# 22        List of users (Marketing consent)         KMIT       Done
# 29                     Branch visualization         KMIT       Done
# 33           App - KiaAccount deletion link          KME       Done
# 37               Remind POP UP Black Friday         KMIT       Done
# 40               verify stripe transactions         KMIT       Done
# 42             FMS- Vehicle deletion failed          KME       Done
# 44               Customer invoice by Stripe          KME       Done
# 45                             Members list         KMIT       Done
# 56                                      tes  bongjoo.kim       Done
# 59                      FMS - Contract type          KME       Done
# 96                  Admin user to be enable         KMIT       Done
# 105              App & FMS - delayed return          KME       Done
# 138  contract detail- deleting test results          KME       Done
# 158                  Customer survey email.          KME  In review
#
#     Reported Date Resolved date
# 5     06-Nov-2020   23-Nov-2020
# 10    18-Nov-2020   14-Dec-2020
# 22    01-Dec-2020   14-Dec-2020
# 29    17-Dec-2020   29-Dec-2020
# 33    29-Dec-2020   28-Apr-2021
# 37    30-Dec-2020   07-Jan-2021
# 40    05-Jan-2021   05-Mar-2021
# 42    06-Jan-2021   18-Feb-2021
# 44    11-Jan-2021   02-Feb-2021
# 45    13-Jan-2021   30-Jan-2021
# 56    15-Feb-2021   24-Feb-2021
# 59    26-Feb-2021   27-May-2021
# 96    25-Mar-2021   30-Mar-2021
# 105   07-Apr-2021   12-Apr-2021
# 138   01-Jun-2021   11-Jun-2021
# 158   27-Jul-2021           NaN

# %%
csv_devops = csv_all.query('Type != \'Bug\' and Type != \'General Inquiries\' and Type != \'Service Request\'')

# %%
csv_devops
# Out:
#     Region            Type         ID  \
# 9      ITA     Improvement   KIMSC-11
# 14     ITA     Improvement   KIMSC-16
# 15     ITA  Service Issues   KIMSC-17
# 17     ITA     Improvement   KIMSC-19
# 18     ITA            Task   KIMSC-20
# ..     ...             ...        ...
# 151    ITA            Task  KIMSC-160
# 153    ITA            Task  KIMSC-162
# 157    ITA     Improvement  KIMSC-166
# 159    ITA            Task  KIMSC-168
# 160    ITA            Task  KIMSC-169
#
#                                            Description Reporter  \
# 9                                [FMS] Base Management      KME
# 14   App - driver's license registration & credit card      KME
# 15                              FMS - EDDS Integration      KME
# 17   KiaMobility fee adjustment offline reservation...     KMIT
# 18                     Hiding License plate in the APP     KMIT
# ..                                                 ...      ...
# 151      FMS - View Reservation Details - button color      KME
# 153        FMS - Vehicle manufacture Kia Motors -> Kia      KME
# 157  Modify Rental insurance premium management det...      HAE
# 159  CLONE - Insert Privacy Link (PDF) in the confi...     KMIT
# 160                  Change Message In KiaMobility APP     KMIT
#
#                     Status Reported Date Resolved date
# 9                     Done   13-Nov-2020   11-Jan-2021
# 14                    Done   20-Nov-2020   07-Jan-2021
# 15                    Done   24-Nov-2020   31-Dec-2020
# 17                    Done   26-Nov-2020   27-Dec-2020
# 18                    Done   27-Nov-2020   27-Dec-2020
# ..                     ...           ...           ...
# 151                   Done   13-Jul-2021   04-Aug-2021
# 153                   Done   13-Jul-2021   04-Aug-2021
# 157  Awaiting confirmation   27-Jul-2021           NaN
# 159  Awaiting confirmation   28-Jul-2021           NaN
# 160              In review   04-Aug-2021           NaN
#
# [76 rows x 8 columns]

# %%
csv_all.describe()
# Out:
#        Region Type        ID                   Description Reporter Status  \
# count     162  162       162                           162      162    162
# unique      1    6       162                           162        5      4
# top       ITA  Bug  KIMSC-10  Niro Scramoncin Not returned     KMIT   Done
# freq      162   70         1                             1       98    140
#
#        Reported Date Resolved date
# count            162           140
# unique            91            66
# top      19-Mar-2021   27-May-2021
# freq               6            26

# %%
from time import gmtime, strftime
>>> strftime("%Y-%m-%d %H:%M:%S", gmtime())
# Out:
# '2021-08-09 05:32:29'

# %%
today = strftime("%Y-%m-%d", gmtime())

# %%
today
# Out:
# '2021-08-09'

# %%
name = "주1회 보고용 " + today
print(name)
writer = pd.ExcelWriter(name+".xlsx", engine = 'xlsxwriter')
csv_all.to_excel(writer, sheet_name="all")
csv_bug.to_excel(writer, sheet_name="bug")
csv_inq.to_excel(writer, sheet_name='inq')
csv_devops.to_excel(writer, sheet_name='devops')
writer.save()
writer.close()
# Out:
# 주1회 보고용 2021-08-09
# C:\Users\E681013\Anaconda3\lib\site-packages\xlsxwriter\workbook.py:329: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
# 차트용으로 작성

csv_status = csv_all.Status

# %%
a =csv_all.groupby("Status")

# %%
a.count()
# Out:
#                        Region  Type   ID  Description  Reporter  \
# Status
# Awaiting confirmation       7     7    7            7         7
# Done                      140   140  140          140       140
# In development             11    11   11           11        11
# In review                   4     4    4            4         4
#
#                        Reported Date  Resolved date
# Status
# Awaiting confirmation              7              0
# Done                             140            140
# In development                    11              0
# In review                          4              0

# %%
chart = {'General Inquiries':'Ops','Service Request':'Ops',"Service Issues":"DevOps","Improvement":"DevOps",'Task':"DevOps" }
csv_chart = csv_all.replace({"Type":chart})

# %%
Type_chart= csv_chart.groupby("Type")
Status_chart= csv_chart.groupby("Status")

# %%
Type_chart.count().Region
# Out:
# Type
# Bug       70
# DevOps    76
# Ops       16
# Name: Region, dtype: int64

# %%
Status_chart.count().Region
# Out:
# Status
# Awaiting confirmation      7
# Done                     140
# In development            11
# In review                  4
# Name: Region, dtype: int64

# %%
chart_name = "chart_data_raw " + today
writer = pd.ExcelWriter(chart_name+".xlsx", engine = 'xlsxwriter')
Status_chart.count().Region.to_excel(writer, sheet_name="status")
Type_chart.count().Region.to_excel(writer, sheet_name="type")
writer.save()
writer.close()
# Out:
# C:\Users\E681013\Anaconda3\lib\site-packages\xlsxwriter\workbook.py:329: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
